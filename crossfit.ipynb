# %% [markdown]
# ## Crossfit stuff

# %%
import json
import requests
import pandas as pd
import numpy as np
from io import StringIO
from bs4 import BeautifulSoup
import time, datetime

# %% [markdown]
# ## See the Markdown files for the necessary info

# %%
year = 2024
base_url = f'https://c3po.crossfit.com/api/competitions/v2/competitions/games/{year}/leaderboards'
r = requests.get(f'{base_url}')
data = r.json()

# %% [markdown]
# ## Seeing that you may not know how much data is returned, I oblige you to copy the base url and paste it into your browser.
#
# ### Really examine the contents of that json blob before you pick the key you want to access.

# %%
print(list(data.keys()))
# Out:
# ['version', 'dataType', 'query', 'sort', 'pagination', 'competition', 'ordinals', 'leaderboardRows']

# %%
page_count = data['pagination']
comp_info = data['competition']
leaderboard_list = data['leaderboardRows'] # This is a list of dicts
print(f"Leaderboard Length and number of entrants: {len(leaderboard_list)}")

# leaderboard_list is a list of dictionaries
# Pick an index and see what the keys are. Follow the keys in your browser on Pretty-print
leaderboard_list[0].keys()
# Out:
# Leaderboard Length and number of entrants: 39
# dict_keys(['overallRank', 'overallScore', 'nextStage', 'ui', 'entrant', 'scores'])

# %%
comp_year = comp_info['year']
entrant_info = leaderboard_list[0].get('entrant')
entrant_info
# Out:
# {'competitorId': '900251',
#  'competitorName': 'James Sprague',
#  'firstName': 'James',
#  'lastName': 'Sprague',
#  'status': 'ACT',
#  'postCompStatus': '',
#  'gender': 'M',
#  'profilePicS3key': '98726-P900251_9-184.jpg',
#  'countryOfOriginCode': 'US',
#  'countryOfOriginName': 'United States',
#  'countryShortCode': '',
#  'regionId': '34',
#  'regionName': 'North America West',
#  'divisionId': '1',
#  'affiliateId': '967',
#  'affiliateName': 'CrossFit Spokane Valley',
#  'age': '22',
#  'height': '74 in',
#  'weight': '210 lb',
#  'teamCaptain': '0'}

# %%
entrants_info = [entry.get('entrant') for entry in leaderboard_list]
entrants_info
# Out:
# [{'competitorId': '900251',
#   'competitorName': 'James Sprague',
#   'firstName': 'James',
#   'lastName': 'Sprague',
#   'status': 'ACT',
#   'postCompStatus': '',
#   'gender': 'M',
#   'profilePicS3key': '98726-P900251_9-184.jpg',
#   'countryOfOriginCode': 'US',
#   'countryOfOriginName': 'United States',
#   'countryShortCode': '',
#   'regionId': '34',
#   'regionName': 'North America West',
#   'divisionId': '1',
#   'affiliateId': '967',
#   'affiliateName': 'CrossFit Spokane Valley',
#   'age': '22',
#   'height': '74 in',
#   'weight': '210 lb',
#   'teamCaptain': '0'},
#  {'competitorId': '671093',
#   'competitorName': 'Dallin Pepper',
#   'firstName': 'Dallin',
#   'lastName': 'Pepper',
#   'status': 'ACT',
#   'postCompStatus': '',
#   'gender': 'M',
#   'profilePicS3key': 'd5ba0-P671093_6-184.jpg',
#   'countryOfOriginCode': 'US',
#   'countryOfOriginName': 'United States',
#   'countryShortCode': '',
#   'regionId': '35',
#   'regionName': 'North America East',
#   'divisionId': '1',
#   'affiliateId': '23233',
#   'affiliateName': 'CrossFit Tailwinds',
#   'age': '22',
#   'height': '72 in',
#   'weight': '215 lb',
#   'teamCaptain': '0'},
#  {'competitorId': '107101',
#   'competitorName': 'Brent Fikowski',
#   'firstName': 'Brent',
#   'lastName': 'Fikowski',
#   'status': 'ACT',
#   'postCompStatus': '',
#   'gender': 'M',
#   'profilePicS3key': '9c4bb-P107101_11-184.jpg',
#   'countryOfOriginCode': 'CA',
#   'countryOfOriginName': 'Canada',
#   'countryShortCode': '',
#   'regionId': '34',
#   'regionName': 'North America West',
#   'divisionId': '1',
#   'affiliateId': 'None',
#   'affiliateName': '',
#   'age': '33',
#   'height': '74 in',
#   'weight': '220 lb',
#   'teamCaptain': '0'},
#  {'competitorId': '1020449',
#   'competitorName': 'Jayson Hopper',
#   'firstName': 'Jayson',
#   'lastName': 'Hopper',
#   'status': 'ACT',
#   'postCompStatus': '',
#   'gender': 'M',
#   'profilePicS3key': 'da4cc-P1020449_8-184.jpg',
#   'countryOfOriginCode': 'US',
#   'countryOfOriginName': 'United States',
#   'countryShortCode': '',
#   'regionId': '35',
#   'regionName': 'North America East',
#   'divisionId': '1',
#   'affiliateId': '15471',
#   'affiliateName': 'CrossFit Crash',
#   'age': '26',
#   'height': '73 in',
#   'weight': '220 lb',
#   'teamCaptain': '0'},
#  {'competitorId': '158264',
#   'competitorName': 'Patrick Vellner',
#   'firstName': 'Patrick',
#   'lastName': 'Vellner',
#   'status': 'ACT',
#   'postCompStatus': '',
#   'gender': 'M',
#   'profilePicS3key': 'd471c-P158264_7-184.jpg',
#   'countryOfOriginCode': 'CA',
#   'countryOfOriginName': 'Canada',
#   'countryShortCode': '',
#   'regionId': '34',
#   'regionName': 'North America West',
#   'divisionId': '1',
#   'affiliateId': '1918',
#   'affiliateName': 'CrossFit Nanaimo',
#   'age': '34',
#   'height': '71 in',
#   'weight': '195 lb',
#   'teamCaptain': '0'},
#  {'competitorId': '74320',
#   'competitorName': 'Samuel Kwant',
#   'firstName': 'Samuel',
#   'lastName': 'Kwant',
#   'status': 'ACT',
#   'postCompStatus': '',
#   'gender': 'M',
#   'profilePicS3key': 'a9afa-P74320_4-184.jpg',
#   'countryOfOriginCode': 'US',
#   'countryOfOriginName': 'United States',
#   'countryShortCode': '',
#   'regionId': '34',
#   'regionName': 'North America West',
#   'divisionId': '1',
#   'affiliateId': '1261',
#   'affiliateName': 'CrossFit Skagit',
#   'age': '28',
#   'height': '71 in',
#   'weight': '206 lb',
#   'teamCaptain': '0'},
#  {'competitorId': '40955',
#   'competitorName': 'Ricky Garard',
#   'firstName': 'Ricky',
#   'lastName': 'Garard',
#   'status': 'ACT',
#   'postCompStatus': '',
#   'gender': 'M',
#   'profilePicS3key': '89cbe-P40955_10-184.jpg',
#   'countryOfOriginCode': 'AU',
#   'countryOfOriginName': 'Australia',
#   'countryShortCode': '',
#   'regionId': '32',
#   'regionName': 'Oceania',
#   'divisionId': '1',
#   'affiliateId': 'None',
#   'affiliateName': '',
#   'age': '30',
#   'height': '179 cm',
#   'weight': '205 lb',
#   'teamCaptain': '0'},
#  {'competitorId': '811708',
#   'competitorName': 'Justin Medeiros',
#   'firstName': 'Justin',
#   'lastName': 'Medeiros',
#   'status': 'ACT',
#   'postCompStatus': '',
#   'gender': 'M',
#   'profilePicS3key': '672d4-P811708_4-184.jpg',
#   'countryOfOriginCode': 'US',
#   'countryOfOriginName': 'United States',
#   'countryShortCode': '',
#   'regionId': '34',
#   'regionName': 'North America West',
#   'divisionId': '1',
#   'affiliateId': '1792',
#   'affiliateName': 'CrossFit Fort Vancouver',
#   'age': '25',
#   'height': '69 in',
#   'weight': '195 lb',
#   'teamCaptain': '0'},
#  {'competitorId': '975774',
#   'competitorName': 'Roman Khrennikov',
#   'firstName': 'Roman',
#   'lastName': 'Khrennikov',
#   'status': 'ACT',
#   'postCompStatus': '',
#   'gender': 'M',
#   'profilePicS3key': '767cc-P975774_3-184.jpg',
#   'countryOfOriginCode': 'RU',
#   'countryOfOriginName': '',
#   'countryShortCode': '',
#   'regionId': '35',
#   'regionName': 'North America East',
#   'divisionId': '1',
#   'affiliateId': '3220',
#   'affiliateName': 'CrossFit Mayhem',
#   'age': '29',
#   'height': '182 cm',
#   'weight': '103 kg',
#   'teamCaptain': '0'},
#  {'competitorId': '947291',
#   'competitorName': 'Austin Hatfield',
#   'firstName': 'Austin',
#   'lastName': 'Hatfield',
#   'status': 'ACT',
#   'postCompStatus': '',
#   'gender': 'M',
#   'profilePicS3key': '63a40-P947291_7-184.jpg',
#   'countryOfOriginCode': 'US',
#   'countryOfOriginName': 'United States',
#   'countryShortCode': '',
#   'regionId': '35',
#   'regionName': 'North America East',
#   'divisionId': '1',
#   'affiliateId': 'None',
#   'affiliateName': '',
#   'age': '24',
#   'height': '67 in',
#   'weight': '195 lb',
#   'teamCaptain': '0'},
#  {'competitorId': '310970',
#   'competitorName': 'Saxon Panchik',
#   'firstName': 'Saxon',
#   'lastName': 'Panchik',
#   'status': 'ACT',
#   'postCompStatus': '',
#   'gender': 'M',
#   'profilePicS3key': '00087-P310970_11-184.jpg',
#   'countryOfOriginCode': 'US',
#   'countryOfOriginName': 'United States',
#   'countryShortCode': '',
#   'regionId': '35',
#   'regionName': 'North America East',
#   'divisionId': '1',
#   'affiliateId': '6982',
#   'affiliateName': 'CrossFit Nolensville',
#   'age': '28',
#   'height': '69 in',
#   'weight': '185 lb',
#   'teamCaptain': '0'},
#  {'competitorId': '156156',
#   'competitorName': 'Jay Crouch',
#   'firstName': 'Jay',
#   'lastName': 'Crouch',
#   'status': 'WD',
#   'postCompStatus': '',
#   'gender': 'M',
#   'profilePicS3key': '91a9a-P156156_17-184.jpg',
#   'countryOfOriginCode': 'AU',
#   'countryOfOriginName': 'Australia',
#   'countryShortCode': '',
#   'regionId': '32',
#   'regionName': 'Oceania',
#   'divisionId': '1',
#   'affiliateId': 'None',
#   'affiliateName': '',
#   'age': '25',
#   'height': '175 cm',
#   'weight': '88 kg',
#   'teamCaptain': '0'},
#  {'competitorId': '1690',
#   'competitorName': 'Travis Mayer',
#   'firstName': 'Travis',
#   'lastName': 'Mayer',
#   'status': 'ACT',
#   'postCompStatus': '',
#   'gender': 'M',
#   'profilePicS3key': '9de68-P1690_5-184.jpg',
#   'countryOfOriginCode': 'US',
#   'countryOfOriginName': 'United States',
#   'countryShortCode': '',
#   'regionId': '35',
#   'regionName': 'North America East',
#   'divisionId': '1',
#   'affiliateId': '7104',
#   'affiliateName': 'CrossFit UNTD',
#   'age': '33',
#   'height': '71 in',
#   'weight': '204 lb',
#   'teamCaptain': '0'},
#  {'competitorId': '680734',
#   'competitorName': 'Henrik Haapalainen',
#   'firstName': 'Henrik',
#   'lastName': 'Haapalainen',
#   'status': 'ACT',
#   'postCompStatus': '',
#   'gender': 'M',
#   'profilePicS3key': '520e8-P680734_2-184.jpg',
#   'countryOfOriginCode': 'FI',
#   'countryOfOriginName': 'Finland',
#   'countryShortCode': '',
#   'regionId': '29',
#   'regionName': 'Europe',
#   'divisionId': '1',
#   'affiliateId': '7050',
#   'affiliateName': 'CrossFit Basement',
#   'age': '29',
#   'height': '185 cm',
#   'weight': '94 kg',
#   'teamCaptain': '0'},
#  {'competitorId': '926366',
#   'competitorName': 'Jelle Hoste',
#   'firstName': 'Jelle',
#   'lastName': 'Hoste',
#   'status': 'ACT',
#   'postCompStatus': '',
#   'gender': 'M',
#   'profilePicS3key': '5d718-P926366_5-184.jpg',
#   'countryOfOriginCode': 'BE',
#   'countryOfOriginName': 'Belgium',
#   'countryShortCode': '',
#   'regionId': '29',
#   'regionName': 'Europe',
#   'divisionId': '1',
#   'affiliateId': '14886',
#   'affiliateName': 'CrossFit Kortrijk',
#   'age': '29',
#   'height': '190 cm',
#   'weight': '100 kg',
#   'teamCaptain': '0'},
#  {'competitorId': '81616',
#   'competitorName': 'Björgvin Karl Guðmundsson',
#   'firstName': 'Björgvin Karl',
#   'lastName': 'Guðmundsson',
#   'status': 'ACT',
#   'postCompStatus': '',
#   'gender': 'M',
#   'profilePicS3key': '4c5dc-P81616_4-184.jpg',
#   'countryOfOriginCode': 'IS',
#   'countryOfOriginName': 'Iceland',
#   'countryShortCode': '',
#   'regionId': '29',
#   'regionName': 'Europe',
#   'divisionId': '1',
#   'affiliateId': '2025',
#   'affiliateName': 'CrossFit Reykjavík',
#   'age': '31',
#   'height': '178 cm',
#   'weight': '190 lb',
#   'teamCaptain': '0'},
#  {'competitorId': '1718365',
#   'competitorName': 'Cole Greashaber',
#   'firstName': 'Cole',
#   'lastName': 'Greashaber',
#   'status': 'ACT',
#   'postCompStatus': '',
#   'gender': 'M',
#   'profilePicS3key': '0a81b-P1718365_3-184.jpg',
#   'countryOfOriginCode': 'US',
#   'countryOfOriginName': 'United States',
#   'countryShortCode': '',
#   'regionId': '34',
#   'regionName': 'North America West',
#   'divisionId': '1',
#   'affiliateId': '3562',
#   'affiliateName': "CrossFit O'Fallon",
#   'age': '24',
#   'height': '72 in',
#   'weight': '212 lb',
#   'teamCaptain': '0'},
#  {'competitorId': '1135386',
#   'competitorName': 'Aniol Ekai',
#   'firstName': 'Aniol',
#   'lastName': 'Ekai',
#   'status': 'ACT',
#   'postCompStatus': '',
#   'gender': 'M',
#   'profilePicS3key': 'd4fd7-P1135386_1-184.jpg',
#   'countryOfOriginCode': 'ES',
#   'countryOfOriginName': 'Spain',
#   'countryShortCode': '',
#   'regionId': '29',
#   'regionName': 'Europe',
#   'divisionId': '1',
#   'affiliateId': '17272',
#   'affiliateName': 'CrossFit Zarautz',
#   'age': '27',
#   'height': '187 cm',
#   'weight': '96 kg',
#   'teamCaptain': '0'},
#  {'competitorId': '2082854',
#   'competitorName': 'Chris Ibarra',
#   'firstName': 'Chris',
#   'lastName': 'Ibarra',
#   'status': 'ACT',
#   'postCompStatus': '',
#   'gender': 'M',
#   'profilePicS3key': '396c5-P2082854_4-184.jpg',
#   'countryOfOriginCode': 'US',
#   'countryOfOriginName': 'United States',
#   'countryShortCode': '',
#   'regionId': '34',
#   'regionName': 'North America West',
#   'divisionId': '1',
#   'affiliateId': '3623',
#   'affiliateName': 'Solution 1 CrossFit',
#   'age': '24',
#   'height': '68 in',
#   'weight': '198 lb',
#   'teamCaptain': '0'},
#  {'competitorId': '771441',
#   'competitorName': 'Calum Clements',
#   'firstName': 'Calum',
#   'lastName': 'Clements',
#   'status': 'ACT',
#   'postCompStatus': '',
#   'gender': 'M',
#   'profilePicS3key': 'f4c5e-P771441_2-184.jpg',
#   'countryOfOriginCode': 'ES',
#   'countryOfOriginName': 'Spain',
#   'countryShortCode': '',
#   'regionId': '29',
#   'regionName': 'Europe',
#   'divisionId': '1',
#   'affiliateId': 'None',
#   'affiliateName': '',
#   'age': '27',
#   'height': '185 cm',
#   'weight': '95 kg',
#   'teamCaptain': '0'},
#  {'competitorId': '1312584',
#   'competitorName': 'Harry Lightfoot',
#   'firstName': 'Harry',
#   'lastName': 'Lightfoot',
#   'status': 'ACT',
#   'postCompStatus': '',
#   'gender': 'M',
#   'profilePicS3key': '0ffe1-P1312584_3-184.jpg',
#   'countryOfOriginCode': 'GB',
#   'countryOfOriginName': 'United Kingdom',
#   'countryShortCode': '',
#   'regionId': '29',
#   'regionName': 'Europe',
#   'divisionId': '1',
#   'affiliateId': '8321',
#   'affiliateName': 'Blueprint CrossFit',
#   'age': '25',
#   'height': '173 cm',
#   'weight': '90 kg',
#   'teamCaptain': '0'},
#  {'competitorId': '251546',
#   'competitorName': 'Alexandre Caron',
#   'firstName': 'Alexandre',
#   'lastName': 'Caron',
#   'status': 'ACT',
#   'postCompStatus': '',
#   'gender': 'M',
#   'profilePicS3key': '92bcf-P251546_4-184.jpg',
#   'countryOfOriginCode': 'CA',
#   'countryOfOriginName': 'Canada',
#   'countryShortCode': '',
#   'regionId': '35',
#   'regionName': 'North America East',
#   'divisionId': '1',
#   'affiliateId': '15562',
#   'affiliateName': 'CrossFit Levis',
#   'age': '28',
#   'height': '71 in',
#   'weight': '205 lb',
#   'teamCaptain': '0'},
#  {'competitorId': '2064040',
#   'competitorName': 'Kalyan Souza',
#   'firstName': 'Kalyan',
#   'lastName': 'Souza',
#   'status': 'ACT',
#   'postCompStatus': '',
#   'gender': 'M',
#   'profilePicS3key': '853f2-P2064040_2-184.jpg',
#   'countryOfOriginCode': 'BR',
#   'countryOfOriginName': 'Brazil',
#   'countryShortCode': '',
#   'regionId': '33',
#   'regionName': 'South America',
#   'divisionId': '1',
#   'affiliateId': 'None',
#   'affiliateName': '',
#   'age': '23',
#   'height': '184 cm',
#   'weight': '97 kg',
#   'teamCaptain': '0'},
#  {'competitorId': '153625',
#   'competitorName': 'Cole Sager',
#   'firstName': 'Cole',
#   'lastName': 'Sager',
#   'status': 'ACT',
#   'postCompStatus': '',
#   'gender': 'M',
#   'profilePicS3key': 'ce316-P153625_5-184.jpg',
#   'countryOfOriginCode': 'US',
#   'countryOfOriginName': 'United States',
#   'countryShortCode': '',
#   'regionId': '34',
#   'regionName': 'North America West',
#   'divisionId': '1',
#   'affiliateId': '967',
#   'affiliateName': 'CrossFit Spokane Valley',
#   'age': '33',
#   'height': '71 in',
#   'weight': '200 lb',
#   'teamCaptain': '0'},
#  {'competitorId': '896411',
#   'competitorName': 'Jack Rozema',
#   'firstName': 'Jack',
#   'lastName': 'Rozema',
#   'status': 'ACT',
#   'postCompStatus': '',
#   'gender': 'M',
#   'profilePicS3key': 'abf59-P896411_1-184.jpg',
#   'countryOfOriginCode': 'US',
#   'countryOfOriginName': 'United States',
#   'countryShortCode': '',
#   'regionId': '35',
#   'regionName': 'North America East',
#   'divisionId': '1',
#   'affiliateId': '6856',
#   'affiliateName': 'CrossFit Hard Knox',
#   'age': '28',
#   'height': '69 in',
#   'weight': '205 lb',
#   'teamCaptain': '0'},
#  {'competitorId': '1335018',
#   'competitorName': 'Bruno Marins',
#   'firstName': 'Bruno',
#   'lastName': 'Marins',
#   'status': 'ACT',
#   'postCompStatus': '',
#   'gender': 'M',
#   'profilePicS3key': '3709d-P1335018_6-184.jpg',
#   'countryOfOriginCode': 'BR',
#   'countryOfOriginName': 'Brazil',
#   'countryShortCode': '',
#   'regionId': '33',
#   'regionName': 'South America',
#   'divisionId': '1',
#   'affiliateId': '29871',
#   'affiliateName': 'Newin CrossFit',
#   'age': '27',
#   'height': '187 cm',
#   'weight': '96 kg',
#   'teamCaptain': '0'},
#  {'competitorId': '1546147',
#   'competitorName': 'Luke Parker',
#   'firstName': 'Luke',
#   'lastName': 'Parker',
#   'status': 'ACT',
#   'postCompStatus': '',
#   'gender': 'M',
#   'profilePicS3key': '1d186-P1546147_3-184.jpg',
#   'countryOfOriginCode': 'US',
#   'countryOfOriginName': 'United States',
#   'countryShortCode': '',
#   'regionId': '35',
#   'regionName': 'North America East',
#   'divisionId': '1',
#   'affiliateId': '3220',
#   'affiliateName': 'CrossFit Mayhem',
#   'age': '30',
#   'height': '71 in',
#   'weight': '205 lb',
#   'teamCaptain': '0'},
#  {'competitorId': '479759',
#   'competitorName': 'Bayley Martin',
#   'firstName': 'Bayley',
#   'lastName': 'Martin',
#   'status': 'ACT',
#   'postCompStatus': '',
#   'gender': 'M',
#   'profilePicS3key': 'b0134-P479759_1-184.jpg',
#   'countryOfOriginCode': 'NZ',
#   'countryOfOriginName': 'New Zealand',
#   'countryShortCode': '',
#   'regionId': '32',
#   'regionName': 'Oceania',
#   'divisionId': '1',
#   'affiliateId': '10767',
#   'affiliateName': 'CrossFit Torian',
#   'age': '24',
#   'height': '174 cm',
#   'weight': '82 kg',
#   'teamCaptain': '0'},
#  {'competitorId': '740370',
#   'competitorName': 'Ruan Potgieter',
#   'firstName': 'Ruan',
#   'lastName': 'Potgieter',
#   'status': 'ACT',
#   'postCompStatus': '',
#   'gender': 'M',
#   'profilePicS3key': '6eb9c-P740370_4-184.jpg',
#   'countryOfOriginCode': 'ZA',
#   'countryOfOriginName': 'South Africa',
#   'countryShortCode': '',
#   'regionId': '30',
#   'regionName': 'Africa',
#   'divisionId': '1',
#   'affiliateId': 'None',
#   'affiliateName': '',
#   'age': '27',
#   'height': '182 cm',
#   'weight': '82 kg',
#   'teamCaptain': '0'},
#  {'competitorId': '308651',
#   'competitorName': 'Brandon Luckett',
#   'firstName': 'Brandon',
#   'lastName': 'Luckett',
#   'status': 'ACT',
#   'postCompStatus': '',
#   'gender': 'M',
#   'profilePicS3key': '1d6b0-P308651_6-184.jpg',
#   'countryOfOriginCode': 'US',
#   'countryOfOriginName': 'United States',
#   'countryShortCode': '',
#   'regionId': '34',
#   'regionName': 'North America West',
#   'divisionId': '1',
#   'affiliateId': '14281',
#   'affiliateName': "CrossFit Franco's",
#   'age': '29',
#   'height': '72 in',
#   'weight': '200 lb',
#   'teamCaptain': '0'},
#  {'competitorId': '1597619',
#   'competitorName': 'Peter Ellis',
#   'firstName': 'Peter',
#   'lastName': 'Ellis',
#   'status': 'CUT',
#   'postCompStatus': '',
#   'gender': 'M',
#   'profilePicS3key': '79513-P1597619_11-184.jpg',
#   'countryOfOriginCode': 'AU',
#   'countryOfOriginName': 'Australia',
#   'countryShortCode': '',
#   'regionId': '32',
#   'regionName': 'Oceania',
#   'divisionId': '1',
#   'affiliateId': '28201',
#   'affiliateName': 'CrossFit Generate',
#   'age': '22',
#   'height': '175 cm',
#   'weight': '83 kg',
#   'teamCaptain': '0'},
#  {'competitorId': '672425',
#   'competitorName': 'Arthur Semenov',
#   'firstName': 'Arthur',
#   'lastName': 'Semenov',
#   'status': 'WD',
#   'postCompStatus': '',
#   'gender': 'M',
#   'profilePicS3key': 'f732e-P672425_2-184.jpg',
#   'countryOfOriginCode': 'RU',
#   'countryOfOriginName': '',
#   'countryShortCode': '',
#   'regionId': '28',
#   'regionName': 'Asia',
#   'divisionId': '1',
#   'affiliateId': '14416',
#   'affiliateName': 'Red Tower CrossFit',
#   'age': '31',
#   'height': '75 in',
#   'weight': '222 lb',
#   'teamCaptain': '0'},
#  {'competitorId': '925870',
#   'competitorName': 'Moritz Fiebig',
#   'firstName': 'Moritz',
#   'lastName': 'Fiebig',
#   'status': 'CUT',
#   'postCompStatus': '',
#   'gender': 'M',
#   'profilePicS3key': '7c303-P925870_3-184.jpg',
#   'countryOfOriginCode': 'DE',
#   'countryOfOriginName': 'Germany',
#   'countryShortCode': '',
#   'regionId': '29',
#   'regionName': 'Europe',
#   'divisionId': '1',
#   'affiliateId': 'None',
#   'affiliateName': '',
#   'age': '29',
#   'height': '179 cm',
#   'weight': '95 kg',
#   'teamCaptain': '0'},
#  {'competitorId': '888668',
#   'competitorName': 'Luka Đukić',
#   'firstName': 'Luka',
#   'lastName': 'Đukić',
#   'status': 'CUT',
#   'postCompStatus': '',
#   'gender': 'M',
#   'profilePicS3key': '17147-P888668_2-184.jpg',
#   'countryOfOriginCode': 'RS',
#   'countryOfOriginName': 'Serbia',
#   'countryShortCode': '',
#   'regionId': '29',
#   'regionName': 'Europe',
#   'divisionId': '1',
#   'affiliateId': 'None',
#   'affiliateName': '',
#   'age': '25',
#   'height': '181 cm',
#   'weight': '92 kg',
#   'teamCaptain': '0'},
#  {'competitorId': '686308',
#   'competitorName': 'Guilherme Malheiros',
#   'firstName': 'Guilherme',
#   'lastName': 'Malheiros',
#   'status': 'WD',
#   'postCompStatus': '',
#   'gender': 'M',
#   'profilePicS3key': '685bf-P686308_6-184.jpg',
#   'countryOfOriginCode': 'BR',
#   'countryOfOriginName': 'Brazil',
#   'countryShortCode': '',
#   'regionId': '33',
#   'regionName': 'South America',
#   'divisionId': '1',
#   'affiliateId': '3220',
#   'affiliateName': 'CrossFit Mayhem',
#   'age': '24',
#   'height': '177 cm',
#   'weight': '88 kg',
#   'teamCaptain': '0'},
#  {'competitorId': '469656',
#   'competitorName': 'Jeffrey Adler',
#   'firstName': 'Jeffrey',
#   'lastName': 'Adler',
#   'status': 'CUT',
#   'postCompStatus': '',
#   'gender': 'M',
#   'profilePicS3key': 'e480e-P469656_1-184.jpg',
#   'countryOfOriginCode': 'CA',
#   'countryOfOriginName': 'Canada',
#   'countryShortCode': '',
#   'regionId': '35',
#   'regionName': 'North America East',
#   'divisionId': '1',
#   'affiliateId': '18059',
#   'affiliateName': 'CrossFit Wonderland',
#   'age': '30',
#   'height': '69 in',
#   'weight': '197 lb',
#   'teamCaptain': '0'},
#  {'competitorId': '327636',
#   'competitorName': 'Samuel Cournoyer',
#   'firstName': 'Samuel',
#   'lastName': 'Cournoyer',
#   'status': 'WD',
#   'postCompStatus': '',
#   'gender': 'M',
#   'profilePicS3key': 'f6726-P327636_8-184.jpg',
#   'countryOfOriginCode': 'CA',
#   'countryOfOriginName': 'Canada',
#   'countryShortCode': '',
#   'regionId': '35',
#   'regionName': 'North America East',
#   'divisionId': '1',
#   'affiliateId': 'None',
#   'affiliateName': '',
#   'age': '28',
#   'height': '180 cm',
#   'weight': '205 lb',
#   'teamCaptain': '0'},
#  {'competitorId': '1978208',
#   'competitorName': 'Victor Hoffer',
#   'firstName': 'Victor',
#   'lastName': 'Hoffer',
#   'status': 'WD',
#   'postCompStatus': '',
#   'gender': 'M',
#   'profilePicS3key': 'ff44c-P1978208_8-184.jpg',
#   'countryOfOriginCode': 'FR',
#   'countryOfOriginName': 'France',
#   'countryShortCode': '',
#   'regionId': '29',
#   'regionName': 'Europe',
#   'divisionId': '1',
#   'affiliateId': '16641',
#   'affiliateName': 'CrossFit Grillen',
#   'age': '21',
#   'height': '180 cm',
#   'weight': '87 kg',
#   'teamCaptain': '0'},
#  {'competitorId': '1059467',
#   'competitorName': 'Lazar Đukić',
#   'firstName': 'Lazar',
#   'lastName': 'Đukić',
#   'status': 'WD',
#   'postCompStatus': '',
#   'gender': 'M',
#   'profilePicS3key': '17a2b-P1059467_5-184.jpg',
#   'countryOfOriginCode': 'RS',
#   'countryOfOriginName': 'Serbia',
#   'countryShortCode': '',
#   'regionId': '29',
#   'regionName': 'Europe',
#   'divisionId': '1',
#   'affiliateId': '20389',
#   'affiliateName': 'Nero CrossFit',
#   'age': '28',
#   'height': '182 cm',
#   'weight': '93 kg',
#   'teamCaptain': '0'}]

# %% [markdown]
# ### While the dictionaries are in order of rank, It's wise to grab the `overallRank` values for each leader board row ie {`overallRank` : "1"} for first place

# %%
# Use list comprehension to access the rank values and return a list
ranking_df = pd.DataFrame.from_dict({'Rank':[entry.get('overallRank') for entry in leaderboard_list]})
ranking_df.head()
# Out:
#   Rank
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5

# %%
# Create a dataframe for the list of entrants dictionaries
# We will combine the rank and the entrant info in the next step
entrants_df = pd.DataFrame(entrants_info)
entrants_df.head()
# Out:
#   competitorId   competitorName firstName  lastName status postCompStatus  \
# 0       900251    James Sprague     James   Sprague    ACT
# 1       671093    Dallin Pepper    Dallin    Pepper    ACT
# 2       107101   Brent Fikowski     Brent  Fikowski    ACT
# 3      1020449    Jayson Hopper    Jayson    Hopper    ACT
# 4       158264  Patrick Vellner   Patrick   Vellner    ACT
#
#   gender           profilePicS3key countryOfOriginCode countryOfOriginName  \
# 0      M   98726-P900251_9-184.jpg                  US       United States
# 1      M   d5ba0-P671093_6-184.jpg                  US       United States
# 2      M  9c4bb-P107101_11-184.jpg                  CA              Canada
# 3      M  da4cc-P1020449_8-184.jpg                  US       United States
# 4      M   d471c-P158264_7-184.jpg                  CA              Canada
#
#   countryShortCode regionId          regionName divisionId affiliateId  \
# 0                        34  North America West          1         967
# 1                        35  North America East          1       23233
# 2                        34  North America West          1        None
# 3                        35  North America East          1       15471
# 4                        34  North America West          1        1918
#
#              affiliateName age height  weight teamCaptain
# 0  CrossFit Spokane Valley  22  74 in  210 lb           0
# 1       CrossFit Tailwinds  22  72 in  215 lb           0
# 2                           33  74 in  220 lb           0
# 3           CrossFit Crash  26  73 in  220 lb           0
# 4         CrossFit Nanaimo  34  71 in  195 lb           0

# %%
leaderboard_2024 = pd.concat([ranking_df, entrants_df], axis=1)
leaderboard_2024.head()
# Out:
#   Rank competitorId   competitorName firstName  lastName status  \
# 0    1       900251    James Sprague     James   Sprague    ACT
# 1    2       671093    Dallin Pepper    Dallin    Pepper    ACT
# 2    3       107101   Brent Fikowski     Brent  Fikowski    ACT
# 3    4      1020449    Jayson Hopper    Jayson    Hopper    ACT
# 4    5       158264  Patrick Vellner   Patrick   Vellner    ACT
#
#   postCompStatus gender           profilePicS3key countryOfOriginCode  ...  \
# 0                     M   98726-P900251_9-184.jpg                  US  ...
# 1                     M   d5ba0-P671093_6-184.jpg                  US  ...
# 2                     M  9c4bb-P107101_11-184.jpg                  CA  ...
# 3                     M  da4cc-P1020449_8-184.jpg                  US  ...
# 4                     M   d471c-P158264_7-184.jpg                  CA  ...
#
#   countryShortCode regionId          regionName divisionId affiliateId  \
# 0                        34  North America West          1         967
# 1                        35  North America East          1       23233
# 2                        34  North America West          1        None
# 3                        35  North America East          1       15471
# 4                        34  North America West          1        1918
#
#              affiliateName age height  weight teamCaptain
# 0  CrossFit Spokane Valley  22  74 in  210 lb           0
# 1       CrossFit Tailwinds  22  72 in  215 lb           0
# 2                           33  74 in  220 lb           0
# 3           CrossFit Crash  26  73 in  220 lb           0
# 4         CrossFit Nanaimo  34  71 in  195 lb           0
#
# [5 rows x 21 columns]

# %%
# Check the dtype of each column
# None of them are properly formatted yet but have no fear. We only need the first 3 columns
leaderboard_2024.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Rank                 39 non-null     object
#  1   competitorId         39 non-null     object
#  2   competitorName       39 non-null     object
#  3   firstName            39 non-null     object
#  4   lastName             39 non-null     object
#  5   status               39 non-null     object
#  6   postCompStatus       39 non-null     object
#  7   gender               39 non-null     object
#  8   profilePicS3key      39 non-null     object
#  9   countryOfOriginCode  39 non-null     object
#  10  countryOfOriginName  39 non-null     object
#  11  countryShortCode     39 non-null     object
#  12  regionId             39 non-null     object
#  13  regionName           39 non-null     object
#  14  divisionId           39 non-null     object
#  15  affiliateId          39 non-null     object
#  16  affiliateName        39 non-null     object
#  17  age                  39 non-null     object
#  18  height               39 non-null     object
#  19  weight               39 non-null     object
#  20  teamCaptain          39 non-null     object
# dtypes: object(21)
# memory usage: 6.5+ KB

# %%
# Ther are better ways to name this but I like descriptive names
rank_id_name_df = leaderboard_2024.iloc[:,:3]
rank_id_name_df.head()
# Out:
#   Rank competitorId   competitorName
# 0    1       900251    James Sprague
# 1    2       671093    Dallin Pepper
# 2    3       107101   Brent Fikowski
# 3    4      1020449    Jayson Hopper
# 4    5       158264  Patrick Vellner

# %%
rank_id_name_df.iloc[0]
# Out:
# Rank                          1
# competitorId             900251
# competitorName    James Sprague
# Name: 0, dtype: object

# %% [markdown]
# ## Eventually I'll explain how to scrape the data but today is not that day.
#
# But..... thought process behind the functions below.
#
# Yes I don't need the options to take a list of ids or names but the option is available
#
# ### 1. Unnecessary elif and else in scrape_athlete_data. `rank_id_name_df` should never be empty but you never know.
#
#
# def scrape_athlete_data(rank_id_name_df=None, ids=None, names=None):
#     all_athlete_data = []
# ```python
#     if rank_id_name_df is not None:  # Use DataFrame if provided
#         for index, row in rank_id_name_df.iterrows():
#             rank = row.iloc[0]
#             competitor_id = row.iloc[1] # Changed for iloc to work correctly
#             athlete_name = row.iloc[2]   # Changed for iloc to work correctly
#             all_athlete_data.extend(scrape_individual_athlete(rank, competitor_id, athlete_name))
#     elif ids is not None and names is not None:  # Use lists if provided
#         for competitor_id, athlete_name in zip(ids, names):
#             all_athlete_data.extend(scrape_individual_athlete(rank, competitor_id, athlete_name))
#     else:
#         return pd.DataFrame()  # Return empty DataFrame if no input is provided
# ```
#     if all_athlete_data:
#         all_column_headers = ["podium_place", "id", "name"] + column_headers # add name to the column headers
#         df = pd.DataFrame(all_athlete_data, columns=all_column_headers)
#         return df
#     else:
#         return pd.DataFrame()  # Return empty DataFrame if no data was scraped
#
# ```python
# def scrape_individual_athlete(rank, competitor_id, athlete_name):
#     athlete_data = []
#     url = f"https://games.crossfit.com/athlete/{competitor_id}"
#     response = requests.get(url)
#
#     if response.status_code == 200:
#         soup = BeautifulSoup(response.text, "html.parser")
#         benchmark_stats_table = soup.find('div', id='benchmarkStats')
#
#         if benchmark_stats_table:
#             rows = benchmark_stats_table.find_all("tr")
#             global column_headers # use a global variable so it is accessible outside of the function
#             column_headers = [row.find_all("th")[0].text.strip() for row in rows if row.find_all("th")]
#             column_data = [row.find_all("td")[0].text.strip() for row in rows if row.find_all("td")]
#
#             if column_headers and column_data:
#                 athlete_data_with_id_name = [rank,competitor_id, athlete_name] + column_data
#                 athlete_data.append(athlete_data_with_id_name)
#         else:
#             print(f"No benchmarkStats table found for athlete {athlete_name} : {competitor_id}.")
#     else:
#         print(f"Request failed for athlete {competitor_id} with status code: {response.status_code}")
#     return athlete_data

# %%
def scrape_individual_athlete(rank, competitor_id, athlete_name):
    athlete_data = []
    url = f"https://games.crossfit.com/athlete/{competitor_id}"
    response = requests.get(url)

    if response.status_code == 200:
        soup = BeautifulSoup(response.text, "html.parser")
        benchmark_stats_table = soup.find('div', id='benchmarkStats')

        if benchmark_stats_table:
            rows = benchmark_stats_table.find_all("tr")
            column_headers = [row.find_all("th")[0].text.strip() for row in rows if row.find_all("th")]
            column_data = [row.find_all("td")[0].text.strip() for row in rows if row.find_all("td")]

            if column_headers and column_data:
                athlete_data_with_id_name = [rank,competitor_id, athlete_name] + column_data
                athlete_data.append(athlete_data_with_id_name)
            return athlete_data, column_headers
        else:
            print(f"No benchmarkStats table found for athlete {athlete_name} : {competitor_id}.")
            return [], []  # Return empty lists for both data and headers
    else:
        print(f"Request failed for athlete {competitor_id} with status code: {response.status_code}")
        return [], []  # Return empty lists for both data and headers
    


def scrape_athlete_data(rank_id_name_df):
    all_athlete_data = []
    all_column_headers = ["podium_place", "id", "name"]
    
    for index, row in rank_id_name_df.iterrows():
        rank = row.iloc[0]
        competitor_id = row.iloc[1] 
        athlete_name = row.iloc[2] 
        # all_athlete_data.extend(scrape_individual_athlete(rank, competitor_id, athlete_name))
        athlete_data, column_headers = scrape_individual_athlete(rank, competitor_id, athlete_name)
        
        if athlete_data: # Check if data was scraped for this athlete
            all_athlete_data.extend(athlete_data)
            # print(athlete_data[3:])
            if not all_column_headers[3:]: # Get column headers only once
                all_column_headers.extend(column_headers) # Assuming the first athlete has all the headers
                # all_column_headers.extend(col) # Assuming the first athlete has all the headers
                print(all_column_headers)

    if all_athlete_data:
        df = pd.DataFrame(all_athlete_data, columns=all_column_headers)
        return df
    else:
        return pd.DataFrame()  # Return empty DataFrame if no data was scraped


pd.set_option('future.no_silent_downcasting', True)
df = scrape_athlete_data(rank_id_name_df=rank_id_name_df).replace('--',np.nan)
if not df.empty:
  print(df.head())
else:
  print("No athlete data could be scraped")
# Out:
# ['podium_place', 'id', 'name', 'Back Squat', 'Chad1000x', 'Clean and Jerk', 'Deadlift', 'Fight Gone Bad', 'Filthy 50', 'Fran', 'Grace', 'Helen', 'L1 Benchmark', 'Max Pull-ups', 'Murph', 'Run 5k', 'Snatch', 'Sprint 400m']
# No benchmarkStats table found for athlete Chris Ibarra : 2082854.
# No benchmarkStats table found for athlete Calum Clements : 771441.
#   podium_place       id             name Back Squat Chad1000x Clean and Jerk  \
# 0            1   900251    James Sprague     465 lb     43:50         355 lb
# 1            2   671093    Dallin Pepper     425 lb       NaN         360 lb
# 2            3   107101   Brent Fikowski     435 lb     47:36         355 lb
# 3            4  1020449    Jayson Hopper     475 lb       NaN         390 lb
# 4            5   158264  Patrick Vellner     455 lb       NaN         355 lb
#
#   Deadlift Fight Gone Bad Filthy 50  Fran Grace Helen L1 Benchmark  \
# 0   550 lb            520     17:30  2:10  1:05  7:02          NaN
# 1   550 lb            403       NaN  2:07  1:58   NaN          NaN
# 2   515 lb            NaN       NaN   NaN  1:14  7:08          NaN
# 3   550 lb            408       NaN  2:15  2:00   NaN          NaN
# 4   595 lb            389     20:16  2:14  1:17  9:46          NaN
#
#   Max Pull-ups  Murph Run 5k  Snatch Sprint 400m
# 0           72    NaN  18:00  285 lb        0:59
# 1           50    NaN    NaN  300 lb         NaN
# 2          NaN  43:39  19:33  305 lb         NaN
# 3          NaN    NaN  19:00  300 lb        0:52
# 4           64    NaN  18:50  290 lb        1:06

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 18 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   podium_place    37 non-null     object
#  1   id              37 non-null     object
#  2   name            37 non-null     object
#  3   Back Squat      29 non-null     object
#  4   Chad1000x       3 non-null      object
#  5   Clean and Jerk  29 non-null     object
#  6   Deadlift        29 non-null     object
#  7   Fight Gone Bad  10 non-null     object
#  8   Filthy 50       7 non-null      object
#  9   Fran            20 non-null     object
#  10  Grace           21 non-null     object
#  11  Helen           11 non-null     object
#  12  L1 Benchmark    0 non-null      object
#  13  Max Pull-ups    18 non-null     object
#  14  Murph           1 non-null      object
#  15  Run 5k          16 non-null     object
#  16  Snatch          29 non-null     object
#  17  Sprint 400m     12 non-null     object
# dtypes: object(18)
# memory usage: 5.3+ KB

# %%
import os
path = os.getcwd()+f"{comp_year}_athlete_leaderboard_benchmarkstats.csv"
df.to_csv(path,index=False)

# %%
unclean_data = pd.read_csv(path)
unclean_data.info()
unclean_data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 18 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   podium_place    37 non-null     int64
#  1   id              37 non-null     int64
#  2   name            37 non-null     object
#  3   Back Squat      29 non-null     object
#  4   Chad1000x       3 non-null      object
#  5   Clean and Jerk  29 non-null     object
#  6   Deadlift        29 non-null     object
#  7   Fight Gone Bad  10 non-null     float64
#  8   Filthy 50       7 non-null      object
#  9   Fran            20 non-null     object
#  10  Grace           21 non-null     object
#  11  Helen           11 non-null     object
#  12  L1 Benchmark    0 non-null      float64
#  13  Max Pull-ups    18 non-null     float64
#  14  Murph           1 non-null      object
#  15  Run 5k          16 non-null     object
#  16  Snatch          29 non-null     object
#  17  Sprint 400m     12 non-null     object
# dtypes: float64(3), int64(2), object(13)
# memory usage: 5.3+ KB
#    podium_place       id             name Back Squat Chad1000x Clean and Jerk  \
# 0             1   900251    James Sprague     465 lb     43:50         355 lb
# 1             2   671093    Dallin Pepper     425 lb       NaN         360 lb
# 2             3   107101   Brent Fikowski     435 lb     47:36         355 lb
# 3             4  1020449    Jayson Hopper     475 lb       NaN         390 lb
# 4             5   158264  Patrick Vellner     455 lb       NaN         355 lb
#
#   Deadlift  Fight Gone Bad Filthy 50  Fran Grace Helen  L1 Benchmark  \
# 0   550 lb           520.0     17:30  2:10  1:05  7:02           NaN
# 1   550 lb           403.0       NaN  2:07  1:58   NaN           NaN
# 2   515 lb             NaN       NaN   NaN  1:14  7:08           NaN
# 3   550 lb           408.0       NaN  2:15  2:00   NaN           NaN
# 4   595 lb           389.0     20:16  2:14  1:17  9:46           NaN
#
#    Max Pull-ups  Murph Run 5k  Snatch Sprint 400m
# 0          72.0    NaN  18:00  285 lb        0:59
# 1          50.0    NaN    NaN  300 lb         NaN
# 2           NaN  43:39  19:33  305 lb         NaN
# 3           NaN    NaN  19:00  300 lb        0:52
# 4          64.0    NaN  18:50  290 lb        1:06

# %%
# First clean the data of the missing values '--' and convert weight (lb/kg) to floats
pd.set_option('future.no_silent_downcasting', True)
cleaned_data = unclean_data.map(lambda x: 
    np.nan if x == '--' else ( 
        float(x.replace(' lb', '')) if isinstance(x, str) and x.endswith('lb') else (
            float(x.replace(' kg', '')) * 2.20 if isinstance(x, str) and x.endswith('kg') else (
                int(x) if isinstance(x,str) and x.isdigit() else x
            )
        )
    )
)
cleaned_data.info()
cleaned_data.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 18 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   podium_place    37 non-null     int64
#  1   id              37 non-null     int64
#  2   name            37 non-null     object
#  3   Back Squat      29 non-null     float64
#  4   Chad1000x       3 non-null      object
#  5   Clean and Jerk  29 non-null     float64
#  6   Deadlift        29 non-null     float64
#  7   Fight Gone Bad  10 non-null     float64
#  8   Filthy 50       7 non-null      object
#  9   Fran            20 non-null     object
#  10  Grace           21 non-null     object
#  11  Helen           11 non-null     object
#  12  L1 Benchmark    0 non-null      float64
#  13  Max Pull-ups    18 non-null     float64
#  14  Murph           1 non-null      object
#  15  Run 5k          16 non-null     object
#  16  Snatch          29 non-null     float64
#  17  Sprint 400m     12 non-null     object
# dtypes: float64(7), int64(2), object(9)
# memory usage: 5.3+ KB
#    podium_place       id              name  Back Squat Chad1000x  \
# 0             1   900251     James Sprague       465.0     43:50
# 1             2   671093     Dallin Pepper       425.0       NaN
# 2             3   107101    Brent Fikowski       435.0     47:36
# 3             4  1020449     Jayson Hopper       475.0       NaN
# 4             5   158264   Patrick Vellner       455.0       NaN
# 5             6    74320      Samuel Kwant       460.0       NaN
# 6             7    40955      Ricky Garard       451.0       NaN
# 7             8   811708   Justin Medeiros         NaN       NaN
# 8             9   975774  Roman Khrennikov       473.0       NaN
# 9            10   947291   Austin Hatfield       535.0       NaN
#
#    Clean and Jerk  Deadlift  Fight Gone Bad Filthy 50  Fran Grace Helen  \
# 0           355.0     550.0           520.0     17:30  2:10  1:05  7:02
# 1           360.0     550.0           403.0       NaN  2:07  1:58   NaN
# 2           355.0     515.0             NaN       NaN   NaN  1:14  7:08
# 3           390.0     550.0           408.0       NaN  2:15  2:00   NaN
# 4           355.0     595.0           389.0     20:16  2:14  1:17  9:46
# 5           345.0     530.0             NaN       NaN  2:04  1:47   NaN
# 6           363.0     528.0           490.0     14:50  2:05  1:10  6:45
# 7             NaN       NaN             NaN       NaN   NaN   NaN   NaN
# 8           370.0     572.0             NaN       NaN  2:00  1:10   NaN
# 9           375.0     540.0           430.0       NaN  1:50  1:07   NaN
#
#    L1 Benchmark  Max Pull-ups  Murph Run 5k  Snatch Sprint 400m
# 0           NaN          72.0    NaN  18:00   285.0        0:59
# 1           NaN          50.0    NaN    NaN   300.0         NaN
# 2           NaN           NaN  43:39  19:33   305.0         NaN
# 3           NaN           NaN    NaN  19:00   300.0        0:52
# 4           NaN          64.0    NaN  18:50   290.0        1:06
# 5           NaN          74.0    NaN  18:05   285.0         NaN
# 6           NaN          75.0    NaN  17:32   297.0        0:54
# 7           NaN           NaN    NaN    NaN     NaN         NaN
# 8           NaN          75.0    NaN    NaN   280.0         NaN
# 9           NaN          82.0    NaN  17:52   305.0        0:48

# %%
import re
fully_cleaned_data = cleaned_data.map(lambda x: 
                        ((time.strptime(x,'%M:%S').tm_min * 60) 
                            + time.strptime(x,'%M:%S').tm_sec
                        ) 
                        if isinstance(x, str) and bool(re.match(r'^\d{1,2}:\d{2}$', x)) else x
                        )

# %%
fully_cleaned_data.info()
fully_cleaned_data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 18 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   podium_place    37 non-null     int64
#  1   id              37 non-null     int64
#  2   name            37 non-null     object
#  3   Back Squat      29 non-null     float64
#  4   Chad1000x       3 non-null      float64
#  5   Clean and Jerk  29 non-null     float64
#  6   Deadlift        29 non-null     float64
#  7   Fight Gone Bad  10 non-null     float64
#  8   Filthy 50       7 non-null      float64
#  9   Fran            20 non-null     float64
#  10  Grace           21 non-null     float64
#  11  Helen           11 non-null     float64
#  12  L1 Benchmark    0 non-null      float64
#  13  Max Pull-ups    18 non-null     float64
#  14  Murph           1 non-null      float64
#  15  Run 5k          16 non-null     float64
#  16  Snatch          29 non-null     float64
#  17  Sprint 400m     12 non-null     float64
# dtypes: float64(15), int64(2), object(1)
# memory usage: 5.3+ KB
#    podium_place       id             name  Back Squat  Chad1000x  \
# 0             1   900251    James Sprague       465.0     2630.0
# 1             2   671093    Dallin Pepper       425.0        NaN
# 2             3   107101   Brent Fikowski       435.0     2856.0
# 3             4  1020449    Jayson Hopper       475.0        NaN
# 4             5   158264  Patrick Vellner       455.0        NaN
#
#    Clean and Jerk  Deadlift  Fight Gone Bad  Filthy 50   Fran  Grace  Helen  \
# 0           355.0     550.0           520.0     1050.0  130.0   65.0  422.0
# 1           360.0     550.0           403.0        NaN  127.0  118.0    NaN
# 2           355.0     515.0             NaN        NaN    NaN   74.0  428.0
# 3           390.0     550.0           408.0        NaN  135.0  120.0    NaN
# 4           355.0     595.0           389.0     1216.0  134.0   77.0  586.0
#
#    L1 Benchmark  Max Pull-ups   Murph  Run 5k  Snatch  Sprint 400m
# 0           NaN          72.0     NaN  1080.0   285.0         59.0
# 1           NaN          50.0     NaN     NaN   300.0          NaN
# 2           NaN           NaN  2619.0  1173.0   305.0          NaN
# 3           NaN           NaN     NaN  1140.0   300.0         52.0
# 4           NaN          64.0     NaN  1130.0   290.0         66.0

# %%
fully_cleaned_data.describe()
# Out:
#        podium_place            id  Back Squat    Chad1000x  Clean and Jerk  \
# count     37.000000  3.700000e+01   29.000000     3.000000       29.000000
# mean      20.000000  7.679053e+05  462.427586  2788.666667      359.275862
# std       11.669047  5.561153e+05   32.870557   137.932351       17.494359
# min        1.000000  1.690000e+03  396.000000  2630.000000      316.800000
# 25%       10.000000  3.086510e+05  435.000000  2743.000000      352.000000
# 50%       21.000000  7.403700e+05  463.000000  2856.000000      360.000000
# 75%       30.000000  1.020449e+06  475.000000  2868.000000      374.000000
# max       38.000000  2.064040e+06  535.000000  2880.000000      395.000000
#
#          Deadlift  Fight Gone Bad    Filthy 50        Fran       Grace  \
# count   29.000000       10.000000     7.000000   20.000000   21.000000
# mean   541.482759      445.700000   984.142857  130.250000   87.857143
# std     27.705880       63.326403   174.152642   11.313127   23.776639
# min    485.000000      337.000000   795.000000  110.000000   65.000000
# 25%    528.000000      404.250000   854.500000  122.750000   70.000000
# 50%    539.000000      438.500000   917.000000  127.500000   77.000000
# 75%    555.000000      505.750000  1126.000000  136.750000  107.000000
# max    600.000000      522.000000  1216.000000  156.000000  146.000000
#
#             Helen  L1 Benchmark  Max Pull-ups   Murph       Run 5k  \
# count   11.000000           0.0     18.000000     1.0    16.000000
# mean   445.727273           NaN     66.222222  2619.0  1129.062500
# std     50.323138           NaN     11.874617     NaN    48.686026
# min    394.000000           NaN     50.000000  2619.0  1052.000000
# 25%    425.000000           NaN     55.500000  2619.0  1082.250000
# 50%    438.000000           NaN     66.500000  2619.0  1141.000000
# 75%    451.000000           NaN     75.000000  2619.0  1168.500000
# max    586.000000           NaN     85.000000  2619.0  1200.000000
#
#            Snatch  Sprint 400m
# count   29.000000    12.000000
# mean   290.172414    55.666667
# std     12.262920     4.696872
# min    264.000000    48.000000
# 25%    280.000000    53.500000
# 50%    290.000000    54.500000
# 75%    300.000000    59.000000
# max    310.000000    66.000000

# %%
path = os.getcwd()+f"cleaned_{comp_year}_athlete_leaderboard_benchmarkstats.csv"
fully_cleaned_data.to_csv(path,index=False)
